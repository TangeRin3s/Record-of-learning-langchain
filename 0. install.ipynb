# %% [markdown]
# conda create          # 创建环境<br>
# -n langchain          # 环境名叫 langchain<br>
# python=3.11           # 指定 Python 版本<br>
# -y                    # 自动确认<br>

# %%
# !conda create -n langchain python=3.11 -y
# !conda activate langchain
# Out:
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\15509\anaconda3\envs\langchain
#
#   added / updated specs:
#     - python=3.11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     expat-2.7.3                |       h885b0b7_4          31 KB
#     libexpat-2.7.3             |       h885b0b7_4         119 KB
#     ------------------------------------------------------------
#                                            Total:         151 KB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              pkgs/main/win-64::bzip2-1.0.8-h2bbff1b_6
#   ca-certificates    pkgs/main/win-64::ca-certificates-2025.12.2-haa95532_0
#   expat              pkgs/main/win-64::expat-2.7.3-h885b0b7_4
#   libexpat           pkgs/main/win-64::libexpat-2.7.3-h885b0b7_4
#   libffi             pkgs/main/win-64::libffi-3.4.4-hd77b12b_1
#   libzlib            pkgs/main/win-64::libzlib-1.3.1-h02ab6af_0
#   openssl            pkgs/main/win-64::openssl-3.0.18-h543e019_0
#   pip                pkgs/main/noarch::pip-25.3-pyhc872135_0
#   python             pkgs/main/win-64::python-3.11.14-h981015d_0
#   setuptools         pkgs/main/win-64::setuptools-80.9.0-py311haa95532_0
#   sqlite             pkgs/main/win-64::sqlite-3.51.0-hda9a48d_0
#   tk                 pkgs/main/win-64::tk-8.6.15-hf199647_0
#   tzdata             pkgs/main/noarch::tzdata-2025b-h04d1e81_0
#   ucrt               pkgs/main/win-64::ucrt-10.0.22621.0-haa95532_0
#   vc                 pkgs/main/win-64::vc-14.3-h2df5915_10
#   vc14_runtime       pkgs/main/win-64::vc14_runtime-14.44.35208-h4927774_10
#   vs2015_runtime     pkgs/main/win-64::vs2015_runtime-14.44.35208-ha6b5a95_10
#   wheel              pkgs/main/win-64::wheel-0.45.1-py311haa95532_0
#   xz                 pkgs/main/win-64::xz-5.6.4-h4754444_1
#   zlib               pkgs/main/win-64::zlib-1.3.1-h02ab6af_0
#
#
#
# Downloading and Extracting Packages: ...working...
# libexpat-2.7.3       | 119 KB    |            |   0%
#
# expat-2.7.3          | 31 KB     |            |   0%
# libexpat-2.7.3       | 119 KB    | #3         |  13%
#
# expat-2.7.3          | 31 KB     | #####1     |  51%
#
# expat-2.7.3          | 31 KB     | ########## | 100%
# libexpat-2.7.3       | 119 KB    | ########## | 100%
#
# expat-2.7.3          | 31 KB     | ########## | 100%
#
# expat-2.7.3          | 31 KB     | ########## | 100%
# libexpat-2.7.3       | 119 KB    | ########## | 100%
# libexpat-2.7.3       | 119 KB    | ########## | 100%
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate langchain
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !pip install -U langchain
# Requires Python 3.10+
# Out:
# Collecting langchain
#   Using cached langchain-1.1.3-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2.0.0,>=1.1.2 (from langchain)
#   Using cached langchain_core-1.2.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Using cached langgraph-1.0.5-py3-none-any.whl.metadata (7.4 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.1.2->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.1.2->langchain)
#   Downloading langsmith-0.4.59-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (25.0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.1.2->langchain)
#   Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.1.2->langchain)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.1.2->langchain)
#   Using cached uuid_utils-0.12.0-cp39-abi3-win_amd64.whl.metadata (1.1 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.2->langchain)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached langgraph_sdk-0.3.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading ormsgpack-1.12.1-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading orjson-3.11.5-cp311-cp311-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain)
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Collecting anyio (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting certifi (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain)
#   Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain)
#   Downloading urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Using cached langchain-1.1.3-py3-none-any.whl (102 kB)
# Using cached langchain_core-1.2.0-py3-none-any.whl (475 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langgraph-1.0.5-py3-none-any.whl (157 kB)
# Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.3.0-py3-none-any.whl (66 kB)
# Downloading langsmith-0.4.59-py3-none-any.whl (413 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached uuid_utils-0.12.0-cp39-abi3-win_amd64.whl (183 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.5-cp311-cp311-win_amd64.whl (133 kB)
# Downloading ormsgpack-1.12.1-cp311-cp311-win_amd64.whl (115 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, urllib3, typing-inspection, tenacity, pyyaml, pydantic-core, ormsgpack, orjson, jsonpointer, idna, h11, charset_normalizer, certifi, annotated-types, requests, pydantic, jsonpatch, httpcore, anyio, requests-toolbelt, httpx, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    ----------------------------------------  0/30 [zstandard]
#    ----------------------------------------  0/30 [zstandard]
#    - --------------------------------------  1/30 [xxhash]
#    -- -------------------------------------  2/30 [uuid-utils]
#    ---- -----------------------------------  3/30 [urllib3]
#    ---- -----------------------------------  3/30 [urllib3]
#    ---- -----------------------------------  3/30 [urllib3]
#    ---- -----------------------------------  3/30 [urllib3]
#    ---- -----------------------------------  3/30 [urllib3]
#    ---- -----------------------------------  3/30 [urllib3]
#    ---- -----------------------------------  3/30 [urllib3]
#    ---- -----------------------------------  3/30 [urllib3]
#    ---- -----------------------------------  3/30 [urllib3]
#    ---- -----------------------------------  3/30 [urllib3]
#    ---- -----------------------------------  3/30 [urllib3]
#    ----- ----------------------------------  4/30 [typing-inspection]
#    ------ ---------------------------------  5/30 [tenacity]
#    ------ ---------------------------------  5/30 [tenacity]
#    ------ ---------------------------------  5/30 [tenacity]
#    -------- -------------------------------  6/30 [pyyaml]
#    -------- -------------------------------  6/30 [pyyaml]
#    -------- -------------------------------  6/30 [pyyaml]
#    -------- -------------------------------  6/30 [pyyaml]
#    -------- -------------------------------  6/30 [pyyaml]
#    --------- ------------------------------  7/30 [pydantic-core]
#    --------- ------------------------------  7/30 [pydantic-core]
#    --------- ------------------------------  7/30 [pydantic-core]
#    ---------- -----------------------------  8/30 [ormsgpack]
#    ---------- -----------------------------  8/30 [ormsgpack]
#    ------------ ---------------------------  9/30 [orjson]
#    ------------- -------------------------- 10/30 [jsonpointer]
#    -------------- ------------------------- 11/30 [idna]
#    -------------- ------------------------- 11/30 [idna]
#    -------------- ------------------------- 11/30 [idna]
#    -------------- ------------------------- 11/30 [idna]
#    ---------------- ----------------------- 12/30 [h11]
#    ---------------- ----------------------- 12/30 [h11]
#    ---------------- ----------------------- 12/30 [h11]
#    ---------------- ----------------------- 12/30 [h11]
#    ----------------- ---------------------- 13/30 [charset_normalizer]
#    ----------------- ---------------------- 13/30 [charset_normalizer]
#    ----------------- ---------------------- 13/30 [charset_normalizer]
#    ----------------- ---------------------- 13/30 [charset_normalizer]
#    ------------------ --------------------- 14/30 [certifi]
#    -------------------- ------------------- 15/30 [annotated-types]
#    --------------------- ------------------ 16/30 [requests]
#    --------------------- ------------------ 16/30 [requests]
#    --------------------- ------------------ 16/30 [requests]
#    --------------------- ------------------ 16/30 [requests]
#    --------------------- ------------------ 16/30 [requests]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ---------------------- ----------------- 17/30 [pydantic]
#    ------------------------ --------------- 18/30 [jsonpatch]
#    ------------------------ --------------- 18/30 [jsonpatch]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    ------------------------- -------------- 19/30 [httpcore]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [requests-toolbelt]
#    ----------------------------- ---------- 22/30 [httpx]
#    ----------------------------- ---------- 22/30 [httpx]
#    ----------------------------- ---------- 22/30 [httpx]
#    ----------------------------- ---------- 22/30 [httpx]
#    ----------------------------- ---------- 22/30 [httpx]
#    ----------------------------- ---------- 22/30 [httpx]
#    ----------------------------- ---------- 22/30 [httpx]
#    ----------------------------- ---------- 22/30 [httpx]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    -------------------------------- ------- 24/30 [langgraph-sdk]
#    -------------------------------- ------- 24/30 [langgraph-sdk]
#    -------------------------------- ------- 24/30 [langgraph-sdk]
#    -------------------------------- ------- 24/30 [langgraph-sdk]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langchain-core]
#    ---------------------------------- ----- 26/30 [langgraph-checkpoint]
#    ---------------------------------- ----- 26/30 [langgraph-checkpoint]
#    ---------------------------------- ----- 26/30 [langgraph-checkpoint]
#    ---------------------------------- ----- 26/30 [langgraph-checkpoint]
#    ---------------------------------- ----- 26/30 [langgraph-checkpoint]
#    ------------------------------------ --- 27/30 [langgraph-prebuilt]
#    ------------------------------------ --- 27/30 [langgraph-prebuilt]
#    ------------------------------------ --- 27/30 [langgraph-prebuilt]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    ---------------------------------------- 30/30 [langchain]
#
# Successfully installed annotated-types-0.7.0 anyio-4.12.0 certifi-2025.11.12 charset_normalizer-3.4.4 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jsonpatch-1.33 jsonpointer-3.0.0 langchain-1.1.3 langchain-core-1.2.0 langgraph-1.0.5 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.3.0 langsmith-0.4.59 orjson-3.11.5 ormsgpack-1.12.1 pydantic-2.12.5 pydantic-core-2.41.5 pyyaml-6.0.3 requests-2.32.5 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-inspection-0.4.2 urllib3-2.6.2 uuid-utils-0.12.0 xxhash-3.6.0 zstandard-0.25.0

# %%
# Installing the OpenAI integration
# !pip install -U langchain-openai

# Installing the Anthropic integration
#pip install -U langchain-anthropic
# Out:
# Collecting langchain-openai
#   Using cached langchain_openai-1.1.3-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-openai) (1.2.0)
# Collecting openai<3.0.0,>=1.109.1 (from langchain-openai)
#   Downloading openai-2.11.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Using cached tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-openai) (0.4.59)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-openai) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (4.12.0)
# Requirement already satisfied: certifi in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (0.16.0)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Downloading jiter-0.12.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting sniffio (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.3->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.3->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.3->langchain-openai) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2025.11.3-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-openai) (2.6.2)
# Requirement already satisfied: colorama in c:\users\15509\anaconda3\envs\langchain\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Using cached langchain_openai-1.1.3-py3-none-any.whl (84 kB)
# Downloading openai-2.11.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ----------------------------- ---------- 0.8/1.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 3.4 MB/s  0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.12.0-cp311-cp311-win_amd64.whl (204 kB)
# Using cached tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
# Downloading regex-2025.11.3-cp311-cp311-win_amd64.whl (277 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: tqdm, sniffio, regex, jiter, distro, tiktoken, openai, langchain-openai
#
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ----- ---------------------------------- 1/8 [sniffio]
#    ---------- ----------------------------- 2/8 [regex]
#    ---------- ----------------------------- 2/8 [regex]
#    ---------- ----------------------------- 2/8 [regex]
#    --------------- ------------------------ 3/8 [jiter]
#    -------------------- ------------------- 4/8 [distro]
#    -------------------- ------------------- 4/8 [distro]
#    ------------------------- -------------- 5/8 [tiktoken]
#    ------------------------- -------------- 5/8 [tiktoken]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ------------------------------ --------- 6/8 [openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ----------------------------------- ---- 7/8 [langchain-openai]
#    ---------------------------------------- 8/8 [langchain-openai]
#
# Successfully installed distro-1.9.0 jiter-0.12.0 langchain-openai-1.1.3 openai-2.11.0 regex-2025.11.3 sniffio-1.3.1 tiktoken-0.12.0 tqdm-4.67.1
